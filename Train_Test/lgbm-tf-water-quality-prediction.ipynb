# %% [markdown]
# # <span class="title-section w3-xxlarge" id="imports"> Importing Libraries 📚</span>
# <hr>

# %%
import numpy as np 
import pandas as pd 
import os, gc
import glob
import lightgbm as lgb
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler,RobustScaler
import joblib
from sklearn.metrics import log_loss
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # <span class="title-section w3-xxlarge" id="loading"> Loading Meta Data 🗂️ </span>
# <hr>

# %%
train_df = pd.read_csv('../input/tfug-mysuru-water-quality-prediction/train.csv')
test_df = pd.read_csv('../input/tfug-mysuru-water-quality-prediction/test.csv')
submission = pd.read_csv('../input/tfug-mysuru-water-quality-prediction/sample_submission.csv')

# %%
train_df.head()
# Out:
#                                                   id categoryA categoryB  \
# 0  a563699ca2a601c6ac64aa29986a00a90fb42b48741695...    catA_1    catB_0
# 1  91ab3eb3bcf6c8c1c5fe2da9ba671aa5a48c7369d9a50f...    catA_1    catB_0
# 2  7128c51c554735d6c81862684ad6005ae12d2edbcd4644...   catA_15    catB_0
# 3  c8144b52e4f63014de0a0d8e1c629bf0b05cb2696cfc23...    catA_0    catB_0
# 4  88d15a5b2df6692f23d105ff1ae82ae026be00c9271eef...   catA_22    catB_0
#
#    categoryC categoryD categoryE categoryF   featureA  featureB  featureC  \
# 0   catC_718    catD_0    catE_0    catF_0  75808.375  4.457840  0.005718
# 1  catC_1309    catD_0    catE_0    catF_0  75808.375  4.457840  0.005718
# 2  catC_1309    catD_0    catE_0    catF_0  75808.375  4.457840  0.005718
# 3   catC_935    catD_0    catE_0    catF_0  75808.375  4.457840  0.005718
# 4  catC_1325    catD_0    catE_2    catF_0 -40055.250  4.363288  0.729194
#
#    ...  compositionC  compositionD  compositionE  compositionF  compositionG  \
# 0  ...          26.0           0.0          32.0           3.0           0.0
# 1  ...          26.0           0.0          32.0           3.0           0.0
# 2  ...          26.0           0.0          32.0           3.0           0.0
# 3  ...          26.0           0.0          32.0           3.0           0.0
# 4  ...          14.0           0.0          49.0           3.0           2.0
#
#    compositionH  compositionI  compositionJ     unit    result
# 0           9.0         22.26          20.0   unit_6  0.000458
# 1           9.0         22.26          20.0   unit_6  0.000335
# 2           9.0         22.26          20.0   unit_4  0.054072
# 3           9.0         22.26          20.0   unit_5  0.061143
# 4           9.0         16.84          15.0  unit_15  0.015439
#
# [5 rows x 28 columns]

# %%
test_df.head()
# Out:
#                                                   id categoryA categoryB  \
# 0  939edadbc8e0cddf21c8c5710c4f2f909abd36c196aee8...    catA_6    catB_0
# 1  fcfed000585350fdc6a982bd1146cd8cdd71d989a2fb01...    catA_6    catB_0
# 2  917b412b73b7c1c83f779d2f350acda4d2b14804579e79...   catA_17    catB_0
# 3  012d646dbd712fd4b752aa8761dc18aaf28643c262f859...    catA_5    catB_0
# 4  77c69c2a873444dfef22131bada7d9504ad731ca8df55d...    catA_5    catB_0
#
#    categoryC categoryD categoryE categoryF    featureA   featureB  featureC  \
# 0    catC_55    catD_0    catE_1    catF_0  325435.125   1.728675  0.032407
# 1  catC_1638    catD_0    catE_0    catF_0   75808.375   4.457840  0.005718
# 2  catC_1400    catD_0   catE_16    catF_0  -19688.875  25.982190  0.000000
# 3   catC_204    catD_0    catE_0    catF_0   75808.375   4.457840  0.005718
# 4  catC_1282    catD_0    catE_2    catF_0  -40055.250   4.363288  0.729194
#
#    ...  compositionB  compositionC  compositionD  compositionE  compositionF  \
# 0  ...           2.2          28.2           2.7          16.7           3.5
# 1  ...          10.0          26.0           0.0          32.0           3.0
# 2  ...          21.4           9.7           0.0          46.7           2.6
# 3  ...          10.0          26.0           0.0          32.0           3.0
# 4  ...           8.0          14.0           0.0          49.0           3.0
#
#    compositionG  compositionH  compositionI  compositionJ     unit
# 0           7.6          20.2         27.25          18.9   unit_7
# 1           0.0           9.0         22.26          20.0   unit_7
# 2           2.4           7.7         21.23           6.1  unit_12
# 3           0.0           9.0         22.26          20.0   unit_0
# 4           2.0           9.0         16.84          15.0   unit_0
#
# [5 rows x 27 columns]

# %%
submission.head()
# Out:
#                                                   id  result
# 0  939edadbc8e0cddf21c8c5710c4f2f909abd36c196aee8...     0.0
# 1  fcfed000585350fdc6a982bd1146cd8cdd71d989a2fb01...     0.0
# 2  917b412b73b7c1c83f779d2f350acda4d2b14804579e79...     0.0
# 3  012d646dbd712fd4b752aa8761dc18aaf28643c262f859...     0.0
# 4  77c69c2a873444dfef22131bada7d9504ad731ca8df55d...     0.0

# %% [markdown]
# # <span class="title-section w3-xxlarge" id="config"> Configuration ⚙️ </span>
# <hr>

# %%
class CFG:
    N_fold=5
    Batch_Size=16
    LR=0.0001
    EPOCHS = 35

# %% [markdown]
# # <span class="title-section w3-xxlarge" id="data_pipeline"> Data Pipeline 🔧 </span>
# <hr>

# %%
categorys=['categoryA','categoryB','categoryC','categoryD','categoryE','categoryF']
itr=[1,2,3,4,5,6]
for i,c in enumerate(categorys):
    train_df[c] = pd.factorize(train_df.iloc[: , itr[i]])[0]
train_df['unit'] = pd.factorize(train_df.iloc[: , -2])[0]


for i,c in enumerate(categorys):
    test_df[c] = pd.factorize(test_df.iloc[: , itr[i]])[0]
test_df['unit'] = pd.factorize(test_df.iloc[: , -2])[0]

# %%
train_df
# Out:
#                                                       id  categoryA  \
# 0      a563699ca2a601c6ac64aa29986a00a90fb42b48741695...          0
# 1      91ab3eb3bcf6c8c1c5fe2da9ba671aa5a48c7369d9a50f...          0
# 2      7128c51c554735d6c81862684ad6005ae12d2edbcd4644...          1
# 3      c8144b52e4f63014de0a0d8e1c629bf0b05cb2696cfc23...          2
# 4      88d15a5b2df6692f23d105ff1ae82ae026be00c9271eef...          3
# ...                                                  ...        ...
# 12995  6dcf9c3ccaf0a92b107d6a78a2cd3ea363350b537444ec...          4
# 12996  e6241d096ea1b88d6e57a92fb6d984825c70de3a4b3ec5...         14
# 12997  081aa272b71b94d3cc665e1484a232b821e9997ed9cc80...         80
# 12998  c50903ae1d6ff475fa20e32fe39ce4429cc6285999a658...          6
# 12999  28ccbfbfd3a19bafd9cb68018aaa59b9ef2750883117ab...         21
#
#        categoryB  categoryC  categoryD  categoryE  categoryF   featureA  \
# 0              0          0          0          0          0  75808.375
# 1              0          1          0          0          0  75808.375
# 2              0          1          0          0          0  75808.375
# 3              0          2          0          0          0  75808.375
# 4              0          3          0          1          0 -40055.250
# ...          ...        ...        ...        ...        ...        ...
# 12995          0        949          0          0          0  75808.375
# 12996          0        930          0          0          0  75808.375
# 12997          0        930          0          0          1  75808.375
# 12998          0       2211          0          8          0  18927.000
# 12999          0       2211          0          8          0  18927.000
#
#         featureB  featureC  ...  compositionC  compositionD  compositionE  \
# 0       4.457840  0.005718  ...         26.00           0.0         32.00
# 1       4.457840  0.005718  ...         26.00           0.0         32.00
# 2       4.457840  0.005718  ...         26.00           0.0         32.00
# 3       4.457840  0.005718  ...         26.00           0.0         32.00
# 4       4.363288  0.729194  ...         14.00           0.0         49.00
# ...          ...       ...  ...           ...           ...           ...
# 12995   4.457840  0.005718  ...         26.00           0.0         32.00
# 12996   4.457840  0.005718  ...         26.00           0.0         32.00
# 12997   4.457840  0.005718  ...         26.00           0.0         32.00
# 12998  21.007457  0.000387  ...         13.13           0.0         35.88
# 12999  21.007457  0.000387  ...         13.13           0.0         35.88
#
#        compositionF  compositionG  compositionH  compositionI  compositionJ  \
# 0               3.0          0.00          9.00         22.26         20.00
# 1               3.0          0.00          9.00         22.26         20.00
# 2               3.0          0.00          9.00         22.26         20.00
# 3               3.0          0.00          9.00         22.26         20.00
# 4               3.0          2.00          9.00         16.84         15.00
# ...             ...           ...           ...           ...           ...
# 12995           3.0          0.00          9.00         22.26         20.00
# 12996           3.0          0.00          9.00         22.26         20.00
# 12997           3.0          0.00          9.00         22.26         20.00
# 12998           1.7          0.73          1.45         28.12         37.83
# 12999           1.7          0.73          1.45         28.12         37.83
#
#        unit    result
# 0         0  0.000458
# 1         0  0.000335
# 2         1  0.054072
# 3         2  0.061143
# 4         3  0.015439
# ...     ...       ...
# 12995     4  0.008260
# 12996    10  0.002395
# 12997    15  0.150982
# 12998     5  0.488908
# 12999    14  0.232833
#
# [13000 rows x 28 columns]

# %%
test_df
# Out:
#                                                      id  categoryA  categoryB  \
# 0     939edadbc8e0cddf21c8c5710c4f2f909abd36c196aee8...          0          0
# 1     fcfed000585350fdc6a982bd1146cd8cdd71d989a2fb01...          0          0
# 2     917b412b73b7c1c83f779d2f350acda4d2b14804579e79...          1          0
# 3     012d646dbd712fd4b752aa8761dc18aaf28643c262f859...          2          0
# 4     77c69c2a873444dfef22131bada7d9504ad731ca8df55d...          2          0
# ...                                                 ...        ...        ...
# 6995  f7a904e2348659e727d933ca229531103b280171fe2519...          2          0
# 6996  9006763de2b19c431ad08584e65d5726c58ffc7037048b...          2          0
# 6997  6e71675534f7806f50c0d35736f0e68c6b1415af31dd82...          7          0
# 6998  0a0569a1eda01c4e3bd9327e13b50294a4b3ef7e223fc8...          2          0
# 6999  f0fee8f7e813afdeaa6ea6d7b3ca3639bb95a20a51291e...          8          0
#
#       categoryC  categoryD  categoryE  categoryF    featureA   featureB  \
# 0             0          0          0          0  325435.125   1.728675
# 1             1          0          1          0   75808.375   4.457840
# 2             2          0          2          0  -19688.875  25.982190
# 3             3          0          1          0   75808.375   4.457840
# 4             4          0          3          0  -40055.250   4.363288
# ...         ...        ...        ...        ...         ...        ...
# 6995       1753          0          3          0  -40055.250   4.363288
# 6996        509          0          1          0   75808.375   4.457840
# 6997       1754          0          3          0  -40055.250   4.363288
# 6998       1632          0          0          0  325435.125   1.728675
# 6999        709          0          1          0   75808.375   4.457840
#
#       featureC  ...  compositionB  compositionC  compositionD  compositionE  \
# 0     0.032407  ...           2.2          28.2           2.7          16.7
# 1     0.005718  ...          10.0          26.0           0.0          32.0
# 2     0.000000  ...          21.4           9.7           0.0          46.7
# 3     0.005718  ...          10.0          26.0           0.0          32.0
# 4     0.729194  ...           8.0          14.0           0.0          49.0
# ...        ...  ...           ...           ...           ...           ...
# 6995  0.729194  ...           8.0          14.0           0.0          49.0
# 6996  0.005718  ...          10.0          26.0           0.0          32.0
# 6997  0.729194  ...           8.0          14.0           0.0          49.0
# 6998  0.032407  ...           2.2          28.2           2.7          16.7
# 6999  0.005718  ...          10.0          26.0           0.0          32.0
#
#       compositionF  compositionG  compositionH  compositionI  compositionJ  \
# 0              3.5           7.6          20.2         27.25          18.9
# 1              3.0           0.0           9.0         22.26          20.0
# 2              2.6           2.4           7.7         21.23           6.1
# 3              3.0           0.0           9.0         22.26          20.0
# 4              3.0           2.0           9.0         16.84          15.0
# ...            ...           ...           ...           ...           ...
# 6995           3.0           2.0           9.0         16.84          15.0
# 6996           3.0           0.0           9.0         22.26          20.0
# 6997           3.0           2.0           9.0         16.84          15.0
# 6998           3.5           7.6          20.2         27.25          18.9
# 6999           3.0           0.0           9.0         22.26          20.0
#
#       unit
# 0        0
# 1        1
# 2        2
# 3        1
# 4        3
# ...    ...
# 6995     3
# 6996     1
# 6997     3
# 6998     0
# 6999     1
#
# [7000 rows x 27 columns]

# %%
ycol = 'result'
feature_names = list(filter(lambda x: x not in [ycol, 'id'], train_df.columns))

# %%
scaler = MinMaxScaler()
train_df[feature_names] = scaler.fit_transform(train_df[feature_names])
test_df[feature_names] = scaler.transform(test_df[feature_names])

# %% [markdown]
# <h1> <span class="title-section w3-xxlarge" id="the_models"> Models Configuration ⚙️ </span> </h1>
# <hr>

# %%
# LightGBM params
lgb_params= {
      'boosting_type':'dart',
      'objective' :'regression',
      'metric':'rmse',
      'tree_learner':'serial',
      'n_estimators':1000,
      'num_leaves':64,
      'max_depth':8,
      'learning_rate':0.1,
      'subsample':0.8,
      'feature_fraction':0.6,
      'reg_alpha':0.1,
      'reg_lambda':0.1,
      'random_state':2023
}

# %% [markdown]
# # <span class="title-section w3-xxlarge" id="training"> Training 🏋️</span>
# <hr>

# %%
model = lgb.LGBMRegressor(**lgb_params)

df_importance_list = []

kfold =KFold(n_splits=5, shuffle=True, random_state=2022)
for fold_id, (trn_idx, val_idx) in enumerate(kfold.split(train_df[feature_names], train_df[ycol])):
    X_train = train_df.iloc[trn_idx][feature_names]
    Y_train = train_df.iloc[trn_idx][ycol]
    X_val = train_df.iloc[val_idx][feature_names]
    Y_val = train_df.iloc[val_idx][ycol]
    lgb_model = model.fit(X_train,
                          Y_train,
                          eval_names=['train', 'valid'],
                          eval_set=[(X_train, Y_train), (X_val, Y_val)],
                          verbose=25,
                          eval_metric='rmse',
                          early_stopping_rounds=50)
    joblib.dump(lgb_model, f'lgb_{fold_id}.pkl')
    df_importance = pd.DataFrame({
        'column': feature_names,
        'importance': lgb_model.feature_importances_,
    })
    df_importance_list.append(df_importance)
    del lgb_model, X_train, Y_train, X_val, Y_val
    gc.collect()
# Out:
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# /opt/conda/lib/python3.7/site-packages/lightgbm/callback.py:223: UserWarning: Early stopping is not available in dart mode
#   _log_warning('Early stopping is not available in dart mode')
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [25]	train's rmse: 0.106145	valid's rmse: 0.109331
# [50]	train's rmse: 0.098508	valid's rmse: 0.102922
# [75]	train's rmse: 0.0820114	valid's rmse: 0.0876806
# [100]	train's rmse: 0.0800626	valid's rmse: 0.0858922
# [125]	train's rmse: 0.0775077	valid's rmse: 0.0836861
# [150]	train's rmse: 0.0775025	valid's rmse: 0.0838539
# [175]	train's rmse: 0.0765077	valid's rmse: 0.0831729
# [200]	train's rmse: 0.076898	valid's rmse: 0.0836047
# [225]	train's rmse: 0.0775941	valid's rmse: 0.0842985
# [250]	train's rmse: 0.0770864	valid's rmse: 0.0838552
# [275]	train's rmse: 0.0762218	valid's rmse: 0.0832675
# [300]	train's rmse: 0.0746972	valid's rmse: 0.0822194
# [325]	train's rmse: 0.0742877	valid's rmse: 0.0821488
# [350]	train's rmse: 0.0736072	valid's rmse: 0.0818463
# [375]	train's rmse: 0.073654	valid's rmse: 0.0819849
# [400]	train's rmse: 0.0733408	valid's rmse: 0.0818431
# [425]	train's rmse: 0.0737102	valid's rmse: 0.082265
# [450]	train's rmse: 0.0730541	valid's rmse: 0.0818389
# [475]	train's rmse: 0.0720367	valid's rmse: 0.0813491
# [500]	train's rmse: 0.0717878	valid's rmse: 0.0813364
# [525]	train's rmse: 0.0719707	valid's rmse: 0.0815057
# [550]	train's rmse: 0.0714832	valid's rmse: 0.0811974
# [575]	train's rmse: 0.0709248	valid's rmse: 0.0810845
# [600]	train's rmse: 0.0711507	valid's rmse: 0.0812756
# [625]	train's rmse: 0.0706588	valid's rmse: 0.0811618
# [650]	train's rmse: 0.0707527	valid's rmse: 0.0812744
# [675]	train's rmse: 0.0705422	valid's rmse: 0.0812938
# [700]	train's rmse: 0.0701916	valid's rmse: 0.0811528
# [725]	train's rmse: 0.0700265	valid's rmse: 0.0811164
# [750]	train's rmse: 0.0699837	valid's rmse: 0.0811475
# [775]	train's rmse: 0.0694779	valid's rmse: 0.0810527
# [800]	train's rmse: 0.0693619	valid's rmse: 0.0810202
# [825]	train's rmse: 0.0692951	valid's rmse: 0.0810408
# [850]	train's rmse: 0.0691588	valid's rmse: 0.0809468
# [875]	train's rmse: 0.069413	valid's rmse: 0.0810823
# [900]	train's rmse: 0.0693758	valid's rmse: 0.0811132
# [925]	train's rmse: 0.0693335	valid's rmse: 0.0810905
# [950]	train's rmse: 0.0688483	valid's rmse: 0.0809157
# [975]	train's rmse: 0.068782	valid's rmse: 0.0808567
# [1000]	train's rmse: 0.0686611	valid's rmse: 0.0808352
# [25]	train's rmse: 0.106368	valid's rmse: 0.108237
# [50]	train's rmse: 0.0986885	valid's rmse: 0.102121
# [75]	train's rmse: 0.0818666	valid's rmse: 0.0880021
# [100]	train's rmse: 0.0798333	valid's rmse: 0.0863801
# [125]	train's rmse: 0.077217	valid's rmse: 0.0845655
# [150]	train's rmse: 0.0771735	valid's rmse: 0.0845606
# [175]	train's rmse: 0.0762843	valid's rmse: 0.0840291
# [200]	train's rmse: 0.0766719	valid's rmse: 0.0843226
# [225]	train's rmse: 0.077392	valid's rmse: 0.0848566
# [250]	train's rmse: 0.0768591	valid's rmse: 0.0844889
# [275]	train's rmse: 0.0758641	valid's rmse: 0.0839837
# [300]	train's rmse: 0.0742737	valid's rmse: 0.0830187
# [325]	train's rmse: 0.0738885	valid's rmse: 0.0830413
# [350]	train's rmse: 0.0731934	valid's rmse: 0.0828907
# [375]	train's rmse: 0.0732099	valid's rmse: 0.0829021
# [400]	train's rmse: 0.0728057	valid's rmse: 0.0827512
# [425]	train's rmse: 0.0732014	valid's rmse: 0.0831638
# [450]	train's rmse: 0.0725872	valid's rmse: 0.0828352
# [475]	train's rmse: 0.0716413	valid's rmse: 0.0824741
# [500]	train's rmse: 0.0713966	valid's rmse: 0.0825085
# [525]	train's rmse: 0.071542	valid's rmse: 0.0825188
# [550]	train's rmse: 0.0710505	valid's rmse: 0.0822086
# [575]	train's rmse: 0.07042	valid's rmse: 0.0822214
# [600]	train's rmse: 0.0706406	valid's rmse: 0.0823167
# [625]	train's rmse: 0.0701283	valid's rmse: 0.0821715
# [650]	train's rmse: 0.0702413	valid's rmse: 0.0822183
# [675]	train's rmse: 0.0700743	valid's rmse: 0.0822224
# [700]	train's rmse: 0.0696915	valid's rmse: 0.0821128
# [725]	train's rmse: 0.0694677	valid's rmse: 0.0820366
# [750]	train's rmse: 0.0694028	valid's rmse: 0.0820483
# [775]	train's rmse: 0.0689408	valid's rmse: 0.0820607
# [800]	train's rmse: 0.068841	valid's rmse: 0.082016
# [825]	train's rmse: 0.0688373	valid's rmse: 0.0820168
# [850]	train's rmse: 0.0687302	valid's rmse: 0.0821197
# [875]	train's rmse: 0.0690652	valid's rmse: 0.0822389
# [900]	train's rmse: 0.0689973	valid's rmse: 0.0821576
# [925]	train's rmse: 0.0689498	valid's rmse: 0.0821384
# [950]	train's rmse: 0.0683885	valid's rmse: 0.0819275
# [975]	train's rmse: 0.0683627	valid's rmse: 0.081942
# [1000]	train's rmse: 0.0682696	valid's rmse: 0.0819001
# [25]	train's rmse: 0.106065	valid's rmse: 0.110816
# [50]	train's rmse: 0.098497	valid's rmse: 0.103589
# [75]	train's rmse: 0.0820123	valid's rmse: 0.0872829
# [100]	train's rmse: 0.08	valid's rmse: 0.0855565
# [125]	train's rmse: 0.0774094	valid's rmse: 0.0831684
# [150]	train's rmse: 0.0774089	valid's rmse: 0.0832897
# [175]	train's rmse: 0.0764055	valid's rmse: 0.0824739
# [200]	train's rmse: 0.0768668	valid's rmse: 0.0830162
# [225]	train's rmse: 0.077601	valid's rmse: 0.0836795
# [250]	train's rmse: 0.0770383	valid's rmse: 0.083327
# [275]	train's rmse: 0.0761201	valid's rmse: 0.0827376
# [300]	train's rmse: 0.0746031	valid's rmse: 0.0815355
# [325]	train's rmse: 0.0742307	valid's rmse: 0.0814216
# [350]	train's rmse: 0.0734469	valid's rmse: 0.0810049
# [375]	train's rmse: 0.0734301	valid's rmse: 0.0810533
# [400]	train's rmse: 0.0731352	valid's rmse: 0.080823
# [425]	train's rmse: 0.0735735	valid's rmse: 0.0814111
# [450]	train's rmse: 0.0729363	valid's rmse: 0.0809988
# [475]	train's rmse: 0.0719538	valid's rmse: 0.0804129
# [500]	train's rmse: 0.0716939	valid's rmse: 0.0804564
# [525]	train's rmse: 0.0718348	valid's rmse: 0.080664
# [550]	train's rmse: 0.0713403	valid's rmse: 0.0802994
# [575]	train's rmse: 0.0707206	valid's rmse: 0.0801475
# [600]	train's rmse: 0.0709491	valid's rmse: 0.0804465
# [625]	train's rmse: 0.0704248	valid's rmse: 0.0802865
# [650]	train's rmse: 0.0705099	valid's rmse: 0.0804168
# [675]	train's rmse: 0.0702968	valid's rmse: 0.0803368
# [700]	train's rmse: 0.0699522	valid's rmse: 0.0801556
# [725]	train's rmse: 0.0697071	valid's rmse: 0.0800903
# [750]	train's rmse: 0.0696036	valid's rmse: 0.0802193
# [775]	train's rmse: 0.0691347	valid's rmse: 0.0800566
# [800]	train's rmse: 0.0690339	valid's rmse: 0.0801027
# [825]	train's rmse: 0.0690025	valid's rmse: 0.0802112
# [850]	train's rmse: 0.0688186	valid's rmse: 0.0802431
# [875]	train's rmse: 0.0691432	valid's rmse: 0.080432
# [900]	train's rmse: 0.0691238	valid's rmse: 0.0803926
# [925]	train's rmse: 0.0690793	valid's rmse: 0.0803597
# [950]	train's rmse: 0.0685695	valid's rmse: 0.0800945
# [975]	train's rmse: 0.0685482	valid's rmse: 0.0801466
# [1000]	train's rmse: 0.0684753	valid's rmse: 0.0801868
# [25]	train's rmse: 0.106705	valid's rmse: 0.108837
# [50]	train's rmse: 0.0991612	valid's rmse: 0.101306
# [75]	train's rmse: 0.0824367	valid's rmse: 0.0862665
# [100]	train's rmse: 0.0804239	valid's rmse: 0.0845892
# [125]	train's rmse: 0.0778552	valid's rmse: 0.0823902
# [150]	train's rmse: 0.0778344	valid's rmse: 0.0824087
# [175]	train's rmse: 0.0768748	valid's rmse: 0.0818112
# [200]	train's rmse: 0.077368	valid's rmse: 0.082276
# [225]	train's rmse: 0.0780162	valid's rmse: 0.0829158
# [250]	train's rmse: 0.0774341	valid's rmse: 0.0825996
# [275]	train's rmse: 0.0765023	valid's rmse: 0.0819941
# [300]	train's rmse: 0.0748557	valid's rmse: 0.0807396
# [325]	train's rmse: 0.0744336	valid's rmse: 0.0807229
# [350]	train's rmse: 0.0737116	valid's rmse: 0.0804158
# [375]	train's rmse: 0.0737809	valid's rmse: 0.0804561
# [400]	train's rmse: 0.0734275	valid's rmse: 0.0803136
# [425]	train's rmse: 0.0738243	valid's rmse: 0.0807612
# [450]	train's rmse: 0.0731771	valid's rmse: 0.0804856
# [475]	train's rmse: 0.0721249	valid's rmse: 0.0799175
# [500]	train's rmse: 0.0717662	valid's rmse: 0.0798586
# [525]	train's rmse: 0.0719721	valid's rmse: 0.0799721
# [550]	train's rmse: 0.0713835	valid's rmse: 0.0796267
# [575]	train's rmse: 0.0707942	valid's rmse: 0.0794327
# [600]	train's rmse: 0.0710183	valid's rmse: 0.07972
# [625]	train's rmse: 0.0705333	valid's rmse: 0.0795011
# [650]	train's rmse: 0.0706438	valid's rmse: 0.0796507
# [675]	train's rmse: 0.0703754	valid's rmse: 0.0795061
# [700]	train's rmse: 0.0699752	valid's rmse: 0.0793736
# [725]	train's rmse: 0.069798	valid's rmse: 0.0793438
# [750]	train's rmse: 0.0697127	valid's rmse: 0.0793925
# [775]	train's rmse: 0.0692519	valid's rmse: 0.0792929
# [800]	train's rmse: 0.0691314	valid's rmse: 0.0793331
# [825]	train's rmse: 0.0691197	valid's rmse: 0.0793939
# [850]	train's rmse: 0.069027	valid's rmse: 0.0794424
# [875]	train's rmse: 0.0693017	valid's rmse: 0.0795985
# [900]	train's rmse: 0.0692613	valid's rmse: 0.0795635
# [925]	train's rmse: 0.0692117	valid's rmse: 0.0794982
# [950]	train's rmse: 0.0686395	valid's rmse: 0.0792991
# [975]	train's rmse: 0.068625	valid's rmse: 0.0793491
# [1000]	train's rmse: 0.0685214	valid's rmse: 0.079325
# [25]	train's rmse: 0.1074	valid's rmse: 0.10379
# [50]	train's rmse: 0.0998777	valid's rmse: 0.0964165
# [75]	train's rmse: 0.0835497	valid's rmse: 0.0805936
# [100]	train's rmse: 0.0816243	valid's rmse: 0.0788343
# [125]	train's rmse: 0.0790312	valid's rmse: 0.0768426
# [150]	train's rmse: 0.0789755	valid's rmse: 0.0768859
# [175]	train's rmse: 0.0780081	valid's rmse: 0.0763237
# [200]	train's rmse: 0.078519	valid's rmse: 0.0767682
# [225]	train's rmse: 0.079272	valid's rmse: 0.0773538
# [250]	train's rmse: 0.0787424	valid's rmse: 0.0769496
# [275]	train's rmse: 0.0778767	valid's rmse: 0.0763738
# [300]	train's rmse: 0.0763498	valid's rmse: 0.0753835
# [325]	train's rmse: 0.0760194	valid's rmse: 0.0753119
# [350]	train's rmse: 0.0752323	valid's rmse: 0.0751809
# [375]	train's rmse: 0.0752286	valid's rmse: 0.0752516
# [400]	train's rmse: 0.0748793	valid's rmse: 0.0750738
# [425]	train's rmse: 0.0752324	valid's rmse: 0.0754384
# [450]	train's rmse: 0.0746587	valid's rmse: 0.0751577
# [475]	train's rmse: 0.0736063	valid's rmse: 0.0747951
# [500]	train's rmse: 0.0733293	valid's rmse: 0.0747841
# [525]	train's rmse: 0.0734004	valid's rmse: 0.0748725
# [550]	train's rmse: 0.0729057	valid's rmse: 0.0746363
# [575]	train's rmse: 0.0723333	valid's rmse: 0.0745583
# [600]	train's rmse: 0.0724769	valid's rmse: 0.0745997
# [625]	train's rmse: 0.0719584	valid's rmse: 0.0744991
# [650]	train's rmse: 0.072047	valid's rmse: 0.0745461
# [675]	train's rmse: 0.0718102	valid's rmse: 0.0745801
# [700]	train's rmse: 0.0715199	valid's rmse: 0.0744883
# [725]	train's rmse: 0.0713296	valid's rmse: 0.07455
# [750]	train's rmse: 0.0712718	valid's rmse: 0.0745914
# [775]	train's rmse: 0.0708219	valid's rmse: 0.0745833
# [800]	train's rmse: 0.0706547	valid's rmse: 0.0745829
# [825]	train's rmse: 0.0705584	valid's rmse: 0.0745898
# [850]	train's rmse: 0.0704704	valid's rmse: 0.0746271
# [875]	train's rmse: 0.0707642	valid's rmse: 0.0747174
# [900]	train's rmse: 0.0707509	valid's rmse: 0.0746582
# [925]	train's rmse: 0.0706989	valid's rmse: 0.0746266
# [950]	train's rmse: 0.070194	valid's rmse: 0.0744595
# [975]	train's rmse: 0.070136	valid's rmse: 0.0745241
# [1000]	train's rmse: 0.0699902	valid's rmse: 0.0744457

# %% [markdown]
# # <span class="title-section w3-xxlarge" id="first_infer">Testing 🔥</span>
# <hr>

# %%
models = []
lgb_model_0 = joblib.load('./lgb_0.pkl')
lgb_model_1 = joblib.load('./lgb_1.pkl')
lgb_model_2 = joblib.load('./lgb_2.pkl')
lgb_model_3 = joblib.load('./lgb_3.pkl')
lgb_model_4 = joblib.load('./lgb_4.pkl')
models.append(lgb_model_0)
models.append(lgb_model_1)
models.append(lgb_model_2)
models.append(lgb_model_3)
models.append(lgb_model_4)

Average_preds= sum([model.predict(test_df[feature_names], verbose=1) for model in models]) / len(models)

# %% [markdown]
# # <span class="title-section w3-xxlarge" id="submit"> Submitting to Kaggle 🇰</span>
# <hr>

# %%
preds = pd.DataFrame(test_df, columns=['id'])
preds['result'] = pd.DataFrame(Average_preds, columns=['result'])
preds.to_csv('submission.csv', index = False)
